# %% [markdown]
# 1.Preparing Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv("/content/group6medicaldataset - Copy.csv")
df
# Out:
#     age     sex     bmi  children smoker     region alcoholic diabetic  \
# 0    19  female  27.900         0    yes  southwest        no       no
# 1    18    male  33.770         1     no  southeast       yes       no
# 2    28    male  33.000         3     no  southeast       yes      yes
# 3    33    male  22.075         0     no  northwest        no      yes
# 4    32    male  28.880         0     no  northwest        no       no
# 5    31  female  25.740         0     no  southeast        no      yes
# 6    46  female  33.440         1     no  southeast        no      yes
# 7    37  female  27.740         3     no  northwest        no       no
# 8    37    male  29.830         2     no  northeast        no       no
# 9    60  female  25.840         0     no  northwest        no      yes
# 10   25    male  26.220         0     no  northeast       yes       no
# 11   62  female  26.290         0    yes  southeast        no       no
# 12   23    male  34.400         0     no  southwest       yes      yes
# 13   56  female  39.820         0     no  southeast        no       no
# 14   27    male  42.130         0    yes  southeast        no      yes
# 15   19    male  24.600         1     no  southwest       yes      yes
# 16   52  female  30.780         1     no  northeast        no      yes
# 17   23    male  23.845         0     no  northeast        no      yes
# 18   56    male  40.300         0     no  southwest        no      yes
# 19   30    male  35.300         0    yes  southwest       yes       no
# 20   60  female  36.005         0     no  northeast        no       no
# 21   30  female  32.400         1     no  southwest       yes      yes
# 22   18    male  34.100         0     no  southeast       yes      yes
# 23   34  female  31.920         1    yes  northeast        no      yes
# 24   37    male  28.025         2     no  northwest        no       no
# 25   59  female  27.720         3     no  southeast        no       no
# 26   63  female  23.085         0     no  northeast        no       no
# 27   55  female  32.775         2     no  northwest        no       no
# 28   23    male  17.385         1     no  northwest        no      yes
# 29   31    male  36.300         2    yes  southwest       yes      yes
# 30   22    male  35.600         0    yes  southwest       yes       no
# 31   18  female  26.315         0     no  northeast       yes      yes
# 32   19  female  28.600         5     no  southwest       yes       no
# 33   63    male  28.310         0     no  northwest        no      yes
# 34   28    male  36.400         1    yes  southwest        no       no
# 35   19    male  20.425         0     no  northwest       yes       no
# 36   62  female  32.965         3     no  northwest        no       no
# 37   26    male  20.800         0     no  southwest       yes       no
# 38   35    male  36.670         1    yes  northeast        no       no
# 39   60    male  39.900         0    yes  southwest        no      yes
# 40   24  female  26.600         0     no  northeast       yes      yes
# 41   31  female  36.630         2     no  northeast        no      yes
# 42   41    male  21.780         1     no  northeast        no      yes
# 43   37  female  30.800         2     no  northeast        no      yes
# 44   38    male  37.050         1     no  northeast        no      yes
# 45   55    male  37.300         0     no  southwest       yes       no
# 46   18  female  38.665         2     no  northeast       yes      yes
# 47   28  female  34.770         0     no  northwest        no      yes
# 48   60  female  24.520         0     no  southeast       yes       no
#
#    heart disease   BP Pre existing disease surgeries  premium
# 0             no   no                  yes       yes     2800
# 1             no   no                  yes       yes     4800
# 2             no   no                   no        no     6800
# 3             no  yes                  yes       yes     5800
# 4            yes  yes                  yes       yes     6200
# 5             no   no                  yes        no     3300
# 6            yes  yes                  yes        no     7400
# 7            yes   no                  yes       yes     7400
# 8             no  yes                   no        no     4600
# 9            yes  yes                   no       yes     9600
# 10            no   no                   no        no     2500
# 11           yes  yes                  yes       yes    16800
# 12            no  yes                   no       yes     5550
# 13           yes  yes                   no       yes     8300
# 14           yes  yes                   no        no     5480
# 15           yes  yes                   no       yes     9600
# 16            no   no                  yes        no     8500
# 17           yes  yes                   no       yes    13500
# 18           yes   no                  yes       yes    27000
# 19            no   no                   no       yes     3650
# 20           yes  yes                  yes       yes    26050
# 21            no   no                   no        no     4250
# 22           yes  yes                   no        no     7250
# 23            no  yes                  yes        no     7250
# 24           yes  yes                  yes        no    11050
# 25           yes  yes                  yes        no    25050
# 26           yes  yes                  yes       yes    32050
# 27           yes   no                  yes       yes    15080
# 28           yes  yes                   no        no    13090
# 29           yes  yes                   no        no    15000
# 30           yes  yes                   no       yes     7250
# 31           yes   no                  yes        no     5600
# 32            no   no                   no       yes     8400
# 33            no   no                   no        no    16050
# 34            no   no                  yes        no     7260
# 35            no   no                  yes        no     3650
# 36            no   no                   no       yes    17050
# 37           yes   no                  yes        no     5980
# 38            no   no                  yes       yes     7390
# 39            no   no                  yes       yes    22050
# 40           yes   no                   no        no     6840
# 41           yes  yes                   no       yes    17050
# 42           yes  yes                   no        no    21050
# 43            no  yes                   no       yes    18050
# 44            no   no                   no       yes    14080
# 45            no  yes                   no       yes    18050
# 46           yes  yes                   no        no    18050
# 47           yes  yes                  yes        no    22080
# 48           yes  yes                  yes       yes    32050

# %%
df.shape
# Out:
# (49, 13)

# %%
df.tail()
# Out:
#     age     sex     bmi  children smoker     region alcoholic diabetic  \
# 44   38    male  37.050         1     no  northeast        no      yes
# 45   55    male  37.300         0     no  southwest       yes       no
# 46   18  female  38.665         2     no  northeast       yes      yes
# 47   28  female  34.770         0     no  northwest        no      yes
# 48   60  female  24.520         0     no  southeast       yes       no
#
#    heart disease   BP Pre existing disease surgeries  premium
# 44            no   no                   no       yes    14080
# 45            no  yes                   no       yes    18050
# 46           yes  yes                   no        no    18050
# 47           yes  yes                  yes        no    22080
# 48           yes  yes                  yes       yes    32050

# %%
df.isnull().sum()
# Out:
# age                     0
# sex                     0
# bmi                     0
# children                0
# smoker                  0
# region                  0
# alcoholic               0
# diabetic                0
# heart disease           0
# BP                      0
# Pre existing disease    0
# surgeries               0
# premium                 0
# dtype: int64

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(df['age'])
plt.title('Age Distribution')
plt.show()
# Out:
# <ipython-input-47-7ec4bc8f949f>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='sex', data=df)
plt.title('Sex Distribution')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['bmi'])
plt.title('BMI Distribution')
plt.show()
# Out:
# <ipython-input-49-b2071bb8387e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bmi'])

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='children', data=df)
plt.title('Children')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='smoker', data=df)
plt.title('smoker')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='region', data=df)
plt.title('region')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='alcoholic', data=df)
plt.title('alcoholic')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='heart disease', data=df)
plt.title('heart disease')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='BP', data=df)
plt.title('BP')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Pre existing disease', data=df)
plt.title('Pre existing disease')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='surgeries', data=df)
plt.title('surgeries')
plt.show()

# %%
df["sex"].value_counts()
# Out:
# sex
# male      26
# female    23
# Name: count, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# smoker
# no     39
# yes    10
# Name: count, dtype: int64

# %%
df["region"].value_counts()
# Out:
# region
# northeast    15
# southwest    13
# northwest    11
# southeast    10
# Name: count, dtype: int64

# %%
df["alcoholic"].value_counts()
# Out:
# alcoholic
# no     31
# yes    18
# Name: count, dtype: int64

# %%
df["diabetic"].value_counts()
# Out:
# diabetic
# yes    26
# no     23
# Name: count, dtype: int64

# %%
df["heart disease"].value_counts()
# Out:
# heart disease
# yes    27
# no     22
# Name: count, dtype: int64

# %%
df["BP"].value_counts()
# Out:
# BP
# yes    27
# no     22
# Name: count, dtype: int64

# %%
df["Pre existing disease"].value_counts()
# Out:
# Pre existing disease
# no     25
# yes    24
# Name: count, dtype: int64

# %%
df["surgeries"].value_counts()
# Out:
# surgeries
# yes    26
# no     23
# Name: count, dtype: int64

# %%
df.replace({"sex":{"male":0,"female":1},
            "smoker":{"yes":0,"no":1},
            "region":{"southeast":0,"southwest":1,"northwest":2,"northeast":3},
            "alcoholic":{"yes":0,"no":1},
            "diabetic":{"yes":0,"no":1},
            "heart disease":{"yes":0,"no":1},
            "BP":{"yes":0,"no":1},
            "Pre existing disease":{"yes":0,"no":1},
            "surgeries":{"yes":0,"no":1}
            },inplace=True)
df
# Out:
#     age  sex     bmi  children  smoker  region  alcoholic  diabetic  \
# 0    19    1  27.900         0       0       1          1         1
# 1    18    0  33.770         1       1       0          0         1
# 2    28    0  33.000         3       1       0          0         0
# 3    33    0  22.075         0       1       2          1         0
# 4    32    0  28.880         0       1       2          1         1
# 5    31    1  25.740         0       1       0          1         0
# 6    46    1  33.440         1       1       0          1         0
# 7    37    1  27.740         3       1       2          1         1
# 8    37    0  29.830         2       1       3          1         1
# 9    60    1  25.840         0       1       2          1         0
# 10   25    0  26.220         0       1       3          0         1
# 11   62    1  26.290         0       0       0          1         1
# 12   23    0  34.400         0       1       1          0         0
# 13   56    1  39.820         0       1       0          1         1
# 14   27    0  42.130         0       0       0          1         0
# 15   19    0  24.600         1       1       1          0         0
# 16   52    1  30.780         1       1       3          1         0
# 17   23    0  23.845         0       1       3          1         0
# 18   56    0  40.300         0       1       1          1         0
# 19   30    0  35.300         0       0       1          0         1
# 20   60    1  36.005         0       1       3          1         1
# 21   30    1  32.400         1       1       1          0         0
# 22   18    0  34.100         0       1       0          0         0
# 23   34    1  31.920         1       0       3          1         0
# 24   37    0  28.025         2       1       2          1         1
# 25   59    1  27.720         3       1       0          1         1
# 26   63    1  23.085         0       1       3          1         1
# 27   55    1  32.775         2       1       2          1         1
# 28   23    0  17.385         1       1       2          1         0
# 29   31    0  36.300         2       0       1          0         0
# 30   22    0  35.600         0       0       1          0         1
# 31   18    1  26.315         0       1       3          0         0
# 32   19    1  28.600         5       1       1          0         1
# 33   63    0  28.310         0       1       2          1         0
# 34   28    0  36.400         1       0       1          1         1
# 35   19    0  20.425         0       1       2          0         1
# 36   62    1  32.965         3       1       2          1         1
# 37   26    0  20.800         0       1       1          0         1
# 38   35    0  36.670         1       0       3          1         1
# 39   60    0  39.900         0       0       1          1         0
# 40   24    1  26.600         0       1       3          0         0
# 41   31    1  36.630         2       1       3          1         0
# 42   41    0  21.780         1       1       3          1         0
# 43   37    1  30.800         2       1       3          1         0
# 44   38    0  37.050         1       1       3          1         0
# 45   55    0  37.300         0       1       1          0         1
# 46   18    1  38.665         2       1       3          0         0
# 47   28    1  34.770         0       1       2          1         0
# 48   60    1  24.520         0       1       0          0         1
#
#     heart disease  BP  Pre existing disease  surgeries  premium
# 0               1   1                     0          0     2800
# 1               1   1                     0          0     4800
# 2               1   1                     1          1     6800
# 3               1   0                     0          0     5800
# 4               0   0                     0          0     6200
# 5               1   1                     0          1     3300
# 6               0   0                     0          1     7400
# 7               0   1                     0          0     7400
# 8               1   0                     1          1     4600
# 9               0   0                     1          0     9600
# 10              1   1                     1          1     2500
# 11              0   0                     0          0    16800
# 12              1   0                     1          0     5550
# 13              0   0                     1          0     8300
# 14              0   0                     1          1     5480
# 15              0   0                     1          0     9600
# 16              1   1                     0          1     8500
# 17              0   0                     1          0    13500
# 18              0   1                     0          0    27000
# 19              1   1                     1          0     3650
# 20              0   0                     0          0    26050
# 21              1   1                     1          1     4250
# 22              0   0                     1          1     7250
# 23              1   0                     0          1     7250
# 24              0   0                     0          1    11050
# 25              0   0                     0          1    25050
# 26              0   0                     0          0    32050
# 27              0   1                     0          0    15080
# 28              0   0                     1          1    13090
# 29              0   0                     1          1    15000
# 30              0   0                     1          0     7250
# 31              0   1                     0          1     5600
# 32              1   1                     1          0     8400
# 33              1   1                     1          1    16050
# 34              1   1                     0          1     7260
# 35              1   1                     0          1     3650
# 36              1   1                     1          0    17050
# 37              0   1                     0          1     5980
# 38              1   1                     0          0     7390
# 39              1   1                     0          0    22050
# 40              0   1                     1          1     6840
# 41              0   0                     1          0    17050
# 42              0   0                     1          1    21050
# 43              1   0                     1          0    18050
# 44              1   1                     1          0    14080
# 45              1   0                     1          0    18050
# 46              0   0                     1          1    18050
# 47              0   0                     0          1    22080
# 48              0   0                     0          0    32050

# %%
x = df.drop(columns='premium', axis=1)
y = df['premium']

# %% [markdown]
# Training Data
#
# Train Test Split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.1,random_state=42)

# %%
x_train.shape
# Out:
# (4, 12)

# %%
y_train.shape
# Out:
# (4,)

# %%
x_test.shape
# Out:
# (45, 12)

# %%
y_test.shape
# Out:
# (45,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_test
# Out:
# array([[ 3.50896288,  1.        ,  1.01124193, -1.73205081,  1.        ,
#         -1.63299316,  0.        ,  1.73205081, -0.57735027, -0.57735027,
#          0.57735027, -1.73205081],
#        [ 3.36573991,  0.        ,  0.76451995, -1.73205081,  1.        ,
#         -0.81649658, -1.        ,  1.73205081,  1.73205081, -0.57735027,
#          0.57735027, -1.73205081],
#        [-0.50128041,  1.        ,  0.51681891, -1.73205081,  1.        ,
#          0.        ,  0.        , -0.57735027, -0.57735027, -0.57735027,
#         -1.73205081,  0.57735027],
#        [ 0.93094934,  0.        ,  0.74004356,  0.57735027,  1.        ,
#          0.81649658,  0.        , -0.57735027,  1.73205081,  1.73205081,
#          0.57735027, -1.73205081],
#        [-1.21739529,  0.        , -0.5527992 , -1.73205081,  1.        ,
#          0.81649658,  0.        , -0.57735027, -0.57735027, -0.57735027,
#          0.57735027, -1.73205081],
#        
        ,  1.73205081, -0.57735027, -0.57735027,
#         -1.73205081, -1.73205081],
#        [ 4.08185478,  1.        ,  0.63773226, -1.73205081,  1.        ,
#          0.81649658,  0.        ,  1.73205081, -0.57735027, -0.57735027,
#         -1.73205081, -1.73205081],
#        [ 0.78772636,  1.        , -0.17145709,  5.19615242,  1.        ,
#          0.        ,  0.        ,  1.73205081, -0.57735027,  1.73205081,
#         -1.73205081, -1.73205081]])

# %% [markdown]
# Building the model
#
# 1)Multiple linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Create and fit the linear regression model
lr = LinearRegression()
lr.fit(x, y)

# Predict the target variable
y_pred = lr.predict(x)

# Calculate the mean squared error (MSE)
mse = mean_squared_error(y, y_pred)

# Calculate the root mean squared error (RMSE)
rmse = mse ** 0.5

# Calculate the R-squared (accuracy) score
accuracy = lr.score(x, y)

print("Mean Squared Error (MSE): {:.2f}".format(mse))
print("Root Mean Squared Error (RMSE): {:.2f}".format(rmse))
print("R-squared (Accuracy): {:.2f}".format(accuracy))
# Out:
# Mean Squared Error (MSE): 22548711.96
# Root Mean Squared Error (RMSE): 4748.55
# R-squared (Accuracy): 0.63

# %% [markdown]
# 2)Random forest regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# Assume x and y are your feature matrix and target variable

# Scale the data using StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# Create a Random Forest regressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the Random Forest model
rf.fit(x_scaled, y)

# Get the feature importances
importances = rf.feature_importances_

# Select the top 5 most important features
idx = importances.argsort()[-5:]
x_selected = x_scaled[:, idx]

# Create and fit a new Random Forest model with the selected features
rf_selected = RandomForestRegressor(n_estimators=100, random_state=42)
rf_selected.fit(x_selected, y)

# Predict the target variable
y_pred = rf_selected.predict(x_selected)

# Calculate the mean squared error (MSE)
mse = mean_squared_error(y, y_pred)

# Calculate the root mean squared error (RMSE)9
rmse = mse ** 0.5

# Calculate the R-squared (accuracy) score
accuracy = rf_selected.score(x_selected, y)

print("Mean Squared Error (MSE): {:.2f}".format(mse))
print("Root Mean Squared Error (RMSE): {:.2f}".format(rmse))
print("R-squared (Accuracy): {:.2f}".format(accuracy))
# Out:
# Mean Squared Error (MSE): 5575653.47
# Root Mean Squared Error (RMSE): 2361.28
# R-squared (Accuracy): 0.91

# %%
import matplotlib.pyplot as plt

# Define the data for the graph
models = ['Multiple Linear Regression', 'Random Forest Regressor']
#mse_values = [22548711.96,5575653.47]
#rmse_values = [4748.55,2361.28]
r2_values = [0.63,0.91]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the MSE values
#ax.plot(models, mse_values, marker='o', label='Mean Squared Error (MSE)')

# Plot the RMSE values
#ax.plot(models, rmse_values, marker='o', label='Root Mean Squared Error (RMSE)')

# Plot the R2 values
ax.plot(models, r2_values, marker='o', label='R-squared (Accuracy)')

# Set the title and labels
ax.set_title('Comparison of Multiple Linear Regression and Random Forest Regressor Models')
ax.set_xlabel('Model')
ax.set_ylabel('Value')

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# Predict charges for a new customer
# Yes=0,No=1

# %%
input_data = [[50,1,40.4,1,1,3,1,1,1,1,1,1]]

# %%
rf.predict(sc.transform(input_data))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([18119.3])

# %%
input_data=[[70,2,40,1,1,3,0,0,0,0,0,0]]
rf.predict(sc.transform(input_data))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([22484.6])
